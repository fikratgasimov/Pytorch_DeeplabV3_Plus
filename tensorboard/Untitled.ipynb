# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
url = 'Segmentation.xlsx'
df = pd.read_excel(url)
df.head(35)
# Out:
#     Accuracy  Class Accuracy      mIoU
# 0   0.966056        0.395604  0.189393
# 1        NaN        0.971100  0.968086
# 2        NaN        0.826721  0.512657
# 3        NaN        0.601718  0.209033
# 4        NaN        0.793019  0.458376
# 5        NaN        0.677925  0.334655
# 6        NaN        0.849880  0.357444
# 7        NaN        0.953679  0.433471
# 8        NaN        0.290445  0.053119
# 9        NaN        0.205097  0.160050
# 10       NaN        0.375466  0.104906
# 11       NaN        0.231530  0.043258
# 12       NaN        0.007622  0.003354
# 13       NaN        0.336670  0.149458

# %%
df.describe()
# Out:
#        Accuracy  Class Accuracy       mIoU
# count  1.000000       14.000000  14.000000
# mean   0.966056        0.536891   0.284090
# std         NaN        0.311845   0.255870
# min    0.966056        0.007622   0.003354
# 25%    0.966056        0.302001   0.116044
# 50%    0.966056        0.498661   0.199213
# 75%    0.966056        0.818295   0.414464
# max    0.966056        0.971100   0.968086

# %%
pd.DataFrame.hist(df, figsize = [15,15]);

# %%
df['mIoU'].value_counts().plot(kind = 'bar')

# %%
sorted_rules=df.sort_values(by=['Class Accuracy','mIoU'],ascending=False).reset_index(drop=True)
sorted_rules.loc[:,['Class Accuracy','mIoU']].plot(title='Metrics')

# %%
df['mIoU'].describe()
# Out:
# count    14.000000
# mean      0.284090
# std       0.255870
# min       0.003354
# 25%       0.116044
# 50%       0.199213
# 75%       0.414464
# max       0.968086
# Name: mIoU, dtype: float64

# %%
df['Class Accuracy'].describe()
# Out:
# count    14.000000
# mean      0.536891
# std       0.311845
# min       0.007622
# 25%       0.302001
# 50%       0.498661
# 75%       0.818295
# max       0.971100
# Name: Class Accuracy, dtype: float64
